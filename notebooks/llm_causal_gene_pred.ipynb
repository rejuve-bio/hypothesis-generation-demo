# %%
import os
from llama_index.core.llms import ChatMessage
from llama_index.llms.openai import OpenAI
from llama_index.llms.ollama import Ollama
from llama_index.llms.anthropic import Anthropic
import pandas as pd
import numpy as np

# %%
BENCHMARK_DIR = "/mnt/hdd_2/abdu/llm_exp/zenodo_directory/data/benchmark_datasets"

# %%
openai_api_key = os.getenv("OPENAI_API_KEY")
anthropic_api_key = os.getenv("ANTHROPIC_API_KEY")
gpt4 = OpenAI(api_key=openai_api_key, model="gpt-4-0613", temperature=0.0)
claude35 = Anthropic(model="claude-3-5-sonnet-20240620", api_key=anthropic_api_key, temperature=0.0)
llama3 = Ollama(model="llama3", request_timeout=120.0, 
             temperature=0.0)

gpt4_response = gpt4.complete("What is the capital of France?")
llama3_response = llama3.complete("What is the capital of France?")
claude_response = claude35.complete("What is the capital of France?")
print(f"gpt4: {gpt4_response}\nllama3: {llama3_response}\nclaude: {claude_response}")
# Out:
# gpt4: The capital of France is Paris.
# llama3: The capital of France is Paris.
# claude: The capital of France is Paris.

# %%
system_prompt = """You are an expert in biology and genetics.

Your task is to identify likely causal genes within a locus for a given GWAS phenotype based on literature evidence.

From the list, provide the likely causal gene (matching one of the given genes), confidence (0: very unsure to 1: very confident), and a brief reason (50 words or less) for your choice.

Return your response in JSON format, excludin g the GWAS phenotype name and gene list in the locus. JSON keys should be ‘causal_gene’,‘confidence’,‘reason’.
Don't add any additional information to the response.
"""

# %%
#OpenTargets
open_target_data = pd.read_table(f"{BENCHMARK_DIR}/opentargets_step2.for_llm.tsv")
open_target_labels = pd.read_table(f"{BENCHMARK_DIR}/opentargets_step2.labels")
open_target_labels.columns = ["ground_truth_symbol", "ground_truth_gene_id"]
open_target_df = pd.concat([open_target_data, open_target_labels], axis=1)
#GWAS Catalog
gwas_catalog_data = pd.read_table(f"{BENCHMARK_DIR}/gwas_catalog_step2.for_llm.tsv")
gwas_catalog_labels = pd.read_table(f"{BENCHMARK_DIR}/gwas_catalog_step2.labels")
gwas_catalog_labels.columns = ["ground_truth_symbol", "ground_truth_gene_id"]
gwas_catalog_df = pd.concat([gwas_catalog_data, gwas_catalog_labels], axis=1)
#Pharmaprojects
pharmaprojects_data = pd.read_table(f"{BENCHMARK_DIR}/pharmaprojects_step2.for_llm.tsv")
pharmaprojects_labels = pd.read_table(f"{BENCHMARK_DIR}/pharmaprojects_step2.labels")
pharmaprojects_labels.columns = ["ground_truth_symbol", "ground_truth_gene_id"]
pharmaprojects_df = pd.concat([pharmaprojects_data, pharmaprojects_labels], axis=1)
open_target_df.head()
# Out:
#    row_number                                        description  \
# 0           1  Carotenoid and tocopherol levels (beta-caroten...
# 1           2                                   Bilirubin levels
# 2           3                                   Bilirubin levels
# 3           4  Sphingolipid levels (SM 14:0Mol%) (sphingomyel...
# 4           5   Fasting glucose-related traits (FPG) (D-Glucose)
#
#                                   symbol_gene_string  \
# 0  {ATMIN},{BCO1},{C16orf46},{CDYL2},{CENPN},{CMC...
# 1  {ATG16L1},{DGKD},{HJURP},{MROH2A},{SAG},{SPP2}...
# 2  {ARHGAP4},{ATP6AP1},{AVPR2},{CTAG1A},{CTAG1B},...
# 3  {ESR2},{GPHB5},{PPP2R5E},{RHOJ},{SGPP1},{SYNE2...
# 4  {ABCB11},{CERS6},{DHRS9},{G6PC2},{LRP2},{NOSTR...
#
#                                  ensembl_gene_string ground_truth_symbol  \
# 0  {ENSG00000103121},{ENSG00000135697},{ENSG00000...                BCO1
# 1  {ENSG00000072080},{ENSG00000077044},{ENSG00000...              UGT1A8
# 2  {ENSG00000007350},{ENSG00000013563},{ENSG00000...                G6PD
# 3  {ENSG00000054654},{ENSG00000126785},{ENSG00000...               SGPP1
# 4  {ENSG00000073734},{ENSG00000073737},{ENSG00000...               G6PC2
#
#   ground_truth_gene_id
# 0      ENSG00000135697
# 1      ENSG00000242366
# 2      ENSG00000160211
# 3      ENSG00000126821
# 4      ENSG00000152254

# %%
gwas_catalog_df.head()
# Out:
#    row_number                                        description  \
# 0           1       High fluorescence immature platelet fraction
# 1           2                         Immature platelet fraction
# 2           3       Metabolite levels (cis-4-decenoate (10:1n6))
# 3           4  Metabolite levels (glutarylcarnitine (C5); glu...
# 4           5  Metabolite levels (imidazole lactate; imidazol...
#
#                                   symbol_gene_string  \
# 0  {ENSG00000239395},{GCSAML},{NLRP3},{OR11L1},{O...
# 1  {ENSG00000239395},{GCSAML},{NLRP3},{OR11L1},{O...
# 2  {ACADM},{ASB17},{MSH4},{RABGGTB},{SLC44A5},{ST...
# 3  {CPT2},{CZIB},{DMRTB1},{ECHDC2},{GLIS1},{LRP8}...
# 4  {GBP1},{GBP2},{GBP3},{GBP4},{GBP5},{GBP6},{GBP...
#
#                                  ensembl_gene_string ground_truth_symbol  \
# 0  {ENSG00000135747},{ENSG00000153230},{ENSG00000...              GCSAML
# 1  {ENSG00000135747},{ENSG00000153230},{ENSG00000...              GCSAML
# 2  {ENSG00000057468},{ENSG00000117054},{ENSG00000...               ACADM
# 3  {ENSG00000116171},{ENSG00000121310},{ENSG00000...                CPT2
# 4  {ENSG00000065243},{ENSG00000117226},{ENSG00000...               KYAT3
#
#   ground_truth_gene_id
# 0      ENSG00000169224
# 1      ENSG00000169224
# 2      ENSG00000117054
# 3      ENSG00000157184
# 4      ENSG00000137944

# %%
pharmaprojects_df.head()
# Out:
#    row_number                                       description  \
# 0           1                  Lysosomal acid lipase deficiency
# 1           2              Recurrent respiratory papillomatosis
# 2           3  Cholestasis, progressive familial intrahepatic 1
# 3           4      Periodic fever, familial, autosomal dominant
# 4           5      Aromatic amino acid decarboxylase deficiency
#
#                                   symbol_gene_string  \
# 0  {ACTA2},{ANKRD22},{CH25H},{FAS},{IFIT1},{IFIT1...
# 1  {C21orf62},{CRYZL1},{DNAJC28},{DONSON},{ENSG00...
# 2  {BIVM},{BIVM-ERCC5},{CCDC168},{ERCC5},{METTL21...
# 3  {CHCHD5},{CKAP2L},{IL1A},{IL1B},{IL1F10},{IL1R...
# 4              {COBL},{DDC},{FIGNL1},{GRB10},{IKZF1}
#
#                                  ensembl_gene_string ground_truth_symbol  \
# 0  {ENSG00000026103},{ENSG00000107796},{ENSG00000...                LIPA
# 1  {ENSG00000142166},{ENSG00000142188},{ENSG00000...              IFNAR2
# 2  {ENSG00000125255},{ENSG00000134897},{ENSG00000...             SLC10A2
# 3  {ENSG00000114999},{ENSG00000115008},{ENSG00000...                IL1B
# 4  {ENSG00000106070},{ENSG00000106078},{ENSG00000...                 DDC
#
#   ground_truth_gene_id
# 0      ENSG00000107798
# 1      ENSG00000159110
# 2      ENSG00000125255
# 3      ENSG00000125538
# 4      ENSG00000132437

# %%
ex_query = "GWAS Phenotype: Type 2 diabetes (type II diabetes mellitus)\n" + \
        "Genes: ADA},{CCN5},{FITM2},{GDAP1L1},{HNF4A},{JPH2},{KCNK15},{OSER1},{PABPC1L},{PKIG},{R3HDML},{RIMS4},{SERINC3},{TOX2},{TTPAL},{YWHAB}"
messages = [
    ChatMessage(
        role="system", content=system_prompt
    ),
    ChatMessage(role="user", content=ex_query),
]
gpt4_response = gpt4.chat(messages)
llama3_response = llama3.chat(messages)
claude_response = claude35.chat(messages)
print(f"gpt4: {gpt4_response}\nllama3: {llama3_response}\nclaude: {claude_response}")
# Out:
# gpt4: assistant: {"causal_gene": "HNF4A", "confidence": 0.8, "reason": "HNF4A is associated with MODY1, a form of diabetes. It plays a crucial role in glucose metabolism and insulin regulation."}
# llama3: assistant: {
# "causal_gene": "HNF4A",
# "confidence": 0.8,
# "reason": "Strong evidence from multiple studies suggests that HNF4A is a key regulator of glucose and insulin homeostasis, making it a strong candidate for type 2 diabetes susceptibility."
# }
# claude: assistant: {
#   "causal_gene": "HNF4A",
#   "confidence": 0.9,
#   "reason": "HNF4A is a well-established transcription factor crucial for pancreatic beta-cell function and insulin secretion. Mutations in HNF4A are associated with maturity-onset diabetes of the young (MODY), a monogenic form of diabetes."
# }

# %%
import json
from tqdm import tqdm

def evaluate_llm_on_benchmark(seed, benchmark_df, num_samples=100):
    np.random.seed(seed)
    total_samples = len(benchmark_df)
    sample_indices = np.random.choice(total_samples, num_samples, replace=False)
    results = {
        "GWAS Phenotype": [],
        "Genes": [],
        "ground_truth_symbol": [],
        "gpt4_pred": [],
        "gpt4_confidence": [],
        "gpt4_reason": [],
        "claude35_pred": [],
        "claude35_confidence": [],
        "claude35_reason": [],
        "llama3_pred": [],
        "llama3_confidence": [],
        "llama3_reason": []
    }
    gpt4_pred = []
    claude35_pred = []
    llama3_pred = []
    for idx in tqdm(sample_indices):
        row = benchmark_df.iloc[idx]
        gwas_phenotype = row["description"]
        genes = row["symbol_gene_string"]
        ground_truth_symbol = row["ground_truth_symbol"]
        query = f"GWAS Phenotype: {gwas_phenotype}\nGenes: {genes}"
        messages = [
            ChatMessage(
                role="system", content=system_prompt
            ),
            ChatMessage(role="user", content=query),
        ]
        gpt4_response = gpt4.chat(messages).message.content
        llama3_response = llama3.chat(messages).message.content
        claude35_response = claude35.chat(messages).message.content
        try:
            gpt4_response = json.loads(gpt4_response)
        except:
            # retry
            gpt4_response = gpt4.chat(messages)
            gpt4_response = json.loads(gpt4_response)
        try:
            llama3_response = json.loads(llama3_response)
        except:
            # retry
            llama3_response = llama3.chat(messages)
            llama3_response = json.loads(llama3_response)
        
        try:
            claude35_response = json.loads(claude35_response)
        except:
            # retry
            claude35_response = claude35.chat(messages)
            claude35_response = json.loads(claude35_response)
        
        if gpt4_response["causal_gene"] in genes:
            if gpt4_response["causal_gene"] == ground_truth_symbol:
                gpt4_pred.append(1)
            else:
                gpt4_pred.append(0)
        else:
            gpt4_pred.append(-1) #hallucination
        
        if claude35_response["causal_gene"] in genes:
            if claude35_response["causal_gene"] == ground_truth_symbol:
                claude35_pred.append(1)
            else:
                claude35_pred.append(0)
        else:
            claude35_pred.append(-1)
        
        if llama3_response["causal_gene"] in genes:
            if llama3_response["causal_gene"] == ground_truth_symbol:
                llama3_pred.append(1)
            else:
                llama3_pred.append(0)
        else:
            llama3_pred.append(-1) #hallucination
        
        
        results["GWAS Phenotype"].append(gwas_phenotype)
        results["Genes"].append(genes)
        results["ground_truth_symbol"].append(ground_truth_symbol)
        results["gpt4_pred"].append(gpt4_response["causal_gene"])
        results["gpt4_confidence"].append(gpt4_response["confidence"])
        results["gpt4_reason"].append(gpt4_response["reason"])
        results["claude35_pred"].append(claude35_response["causal_gene"])
        results["claude35_confidence"].append(claude35_response["confidence"])
        results["claude35_reason"].append(claude35_response["reason"])
        results["llama3_pred"].append(llama3_response["causal_gene"])
        results["llama3_confidence"].append(llama3_response["confidence"])
        results["llama3_reason"].append(llama3_response["reason"])
        
    return results, gpt4_pred, claude35_pred, llama3_pred

# %%
seed = 42
open_target_results, gpt4_pred, claude35_pred, llama3_pred = evaluate_llm_on_benchmark(seed, open_target_df)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 100/100 [09:21<00:00,  5.61s/it]

# %%
n_hallucination_gpt4 = sum([1 for p in gpt4_pred if p == -1])
n_correct_gpt4 = sum([1 for p in gpt4_pred if p == 1])
n_incorrect_gpt4 = sum([1 for p in gpt4_pred if p == 0])

n_hallucination_claud35 = sum([1 for p in claude35_pred if p == -1])
n_correct_claud35 = sum([1 for p in claude35_pred if p == 1])
n_incorrect_claud35 = sum([1 for p in claude35_pred if p == 0])

n_hallucination_llama3 = sum([1 for p in llama3_pred if p == -1])
n_correct_llama3 = sum([1 for p in llama3_pred if p == 1])
n_incorrect_llama3 = sum([1 for p in llama3_pred if p == 0])

print(f"OpenTargets: GPT-4 hallucination: {n_hallucination_gpt4}, correct: {n_correct_gpt4}, incorrect: {n_incorrect_gpt4}")
print(f"OpenTargets: Claude3.5 hallucination: {n_hallucination_claud35}, correct: {n_correct_claud35}, incorrect: {n_incorrect_claud35}")
print(f"OpenTargets: Llama3 hallucination: {n_hallucination_llama3}, correct: {n_correct_llama3}, incorrect: {n_incorrect_llama3}")
# Out:
# OpenTargets: GPT-4 hallucination: 0, correct: 80, incorrect: 20
# OpenTargets: Claude3.5 hallucination: 0, correct: 81, incorrect: 19
# OpenTargets: Llama3 hallucination: 4, correct: 63, incorrect: 33

# %%
gpt4_precision = n_correct_gpt4 / (n_correct_gpt4 + n_incorrect_gpt4)
gpt4_recall = n_correct_gpt4 / (n_correct_gpt4 + n_hallucination_gpt4 + n_incorrect_gpt4)

claude35_precision = n_correct_claud35 / (n_correct_claud35 + n_incorrect_claud35)
claude35_recall = n_correct_claud35 / (n_correct_claud35 + n_hallucination_claud35 + n_incorrect_claud35)

llama3_precision = n_correct_llama3 / (n_correct_llama3 + n_incorrect_llama3)
llama3_recall = n_correct_llama3 / (n_correct_llama3 + n_hallucination_llama3 + n_incorrect_llama3)

gpt4_f1 = 2 * (gpt4_precision * gpt4_recall) / (gpt4_precision + gpt4_recall)
claude35_f1 = 2 * (claude35_precision * claude35_recall) / (claude35_precision + claude35_recall)
llama3_f1 = 2 * (llama3_precision * llama3_recall) / (llama3_precision + llama3_recall)

print(f"OpenTargets: GPT-4 precision: {gpt4_precision}, recall: {gpt4_recall}, F1: {gpt4_f1}")
print(f"OpenTargets: Claude3.5 precision: {claude35_precision}, recall: {claude35_recall}, F1: {claude35_f1}")
print(f"OpenTargets: Llama3 precision: {llama3_precision}, recall: {llama3_recall}, F1: {llama3_f1}")
# Out:
# OpenTargets: GPT-4 precision: 0.8, recall: 0.8, F1: 0.8000000000000002
# OpenTargets: Claude3.5 precision: 0.81, recall: 0.81, F1: 0.81
# OpenTargets: Llama3 precision: 0.65625, recall: 0.63, F1: 0.6428571428571429

# %%
open_target_results_df = pd.DataFrame(open_target_results)
open_target_results_df.head(50)
# Out:
#                                        GWAS Phenotype  \
# 0                                   Total Cholesterol
# 1                                       Heart failure
# 2         Type 2 diabetes (type II diabetes mellitus)
# 3           metabolite: glycine (glycine measurement)
# 4   Disorders of lipoid metabolism (Disorder of li...
# 5         Type 2 diabetes (type II diabetes mellitus)
# 6                                           Psoriasis
# 7   Nerve, nerve root and plexus disorders (periph...
# 8                                 reticulocyte volume
# 9   treatment: statin use (low density lipoprotein...
# 10                                Parkinson's disease
# 11        Type 2 diabetes (type II diabetes mellitus)
# 12                                Psoriatic arthritis
# 13                                Atrial fibrillation
# 14                                          Psoriasis
# 15                                Atrial fibrillation
# 16                                               Gout
# 17                                   Breast carcinoma
# 18  Blood lipid (HDL, LDL, TG, PP, …) (lipid measu...
# 19                          heel bone mineral density
# 20                                  Total Cholesterol
# 21        Type 2 diabetes (type II diabetes mellitus)
# 22       malignant neoplasms of skin (skin carcinoma)
# 23                            Glutamine (L-Glutamine)
# 24  Blood lipid (HDL, LDL, TG, PP, …) (lipid measu...
# 25        leg predicted mass (right) (lean body mass)
# 26                              Citrate (Citric acid)
# 27       arthrosis of hip (heel bone mineral density)
# 28        Psoriatic arthropathy (psoriatic arthritis)
# 29                                 Psoriasis vulgaris
# 30        Type 2 diabetes (type II diabetes mellitus)
# 31                   Breast cancer (breast carcinoma)
# 32        Type 2 diabetes (type II diabetes mellitus)
# 33                                 Prostate carcinoma
# 34        Type 2 diabetes (type II diabetes mellitus)
# 35                   Breast cancer (breast carcinoma)
# 36                                            Glycine
# 37                                      Schizophrenia
# 38                  Stearic acid (18:0) plasma levels
# 39                    Psoriasis and related disorders
# 40  Blood clot in the leg (dvt) (deep vein thrombo...
# 41                                            Obesity
# 42                               Rheumatoid arthritis
# 43                        Fasting Glucose (D-Glucose)
# 44  3-aminoisobutyrate urine (3-Aminoisobutanoic a...
# 45        Type 2 diabetes (type II diabetes mellitus)
# 46  Blood metabolite levels (glutaroyl carnitine) ...
# 47                         Asthma or allergic disease
# 48  Age-related diseases, mortality and associated...
# 49                                       Hypertension
#
#                                                 Genes ground_truth_symbol  \
# 0   {CYP7A1},{FAM110B},{NSMAF},{SDCBP},{TOX},{UBXN2B}              CYP7A1
# 1   {APH1B},{CA12},{DAPK2},{FBXL22},{HERC1},{LACTB...                CA12
# 2   {ARF5},{FSCN3},{GCC1},{GRM8},{PAX4},{SND1},{ZN...                PAX4
# 3                      {ACADL},{CPS1},{LANCL1},{MYL1}                CPS1
# 4   {ANKDD1B},{ANKRD31},{CERT1},{FAM169A},{GCNT4},...               HMGCR
# 5   {BLOC1S4},{C4orf50},{CRMP1},{ENSG00000170846},...                WFS1
# 6                    {EBF1},{IL12B},{RNF145},{UBLCP1}               IL12B
# 7   {CCDC85A},{CCDC88A},{CFAP36},{EFEMP1},{PNPT1},...              EFEMP1
# 8   {AIM2},{CD1A},{CD1B},{CD1C},{CD1D},{CD1E},{IFI...               SPTA1
# 9   {ACP5},{ANGPTL8},{AP1M2},{C19orf38},{CARM1},{C...                LDLR
# 10                   {CCSER1},{GPRIN3},{MMRN1},{SNCA}                SNCA
# 11  {ANKDD1B},{ANKRD31},{CERT1},{HMGCR},{POC5},{PO...                POC5
# 12                   {EBF1},{IL12B},{RNF145},{UBLCP1}               IL12B
# 13      {ARHGAP10},{EDNRA},{NR3C2},{PRMT9},{TMEM184C}               NR3C2
# 14                   {EBF1},{IL12B},{RNF145},{UBLCP1}               IL12B
# 15      {ARHGAP10},{EDNRA},{NR3C2},{PRMT9},{TMEM184C}               NR3C2
# 16  {ARL2},{ARL2-SNX15},{ATG2A},{BAD},{BATF2},{CAT...            SLC22A12
# 17  {ANO1},{CCND1},{ENSG00000287725},{FGF19},{FGF3...               CCND1
# 18  {C20orf173},{CEP250},{CNBD2},{CPNE1},{EDEM2},{...               CPNE1
# 19           {CPED1},{FAM3C},{ING3},{TSPAN12},{WNT16}               WNT16
# 20                   {KCNV2},{PUM3},{SMARCA2},{VLDLR}               VLDLR
# 21  {ACADS},{ANAPC5},{C12orf43},{CABP1},{CAMKK2},{...               HNF1A
# 22      {GABRG3},{GOLGA6L24},{GOLGA8F},{HERC2},{OCA2}                OCA2
# 23  {ANKRD52},{APOF},{ATP5F1B},{BAZ2A},{CNPY2},{CO...                GLS2
# 24   {ANGPTL3},{ATG4C},{DOCK7},{KANK4},{L1TD1},{USP1}             ANGPTL3
# 25                                             {BMP2}                BMP2
# 26  {C22orf39},{CDC45},{CLDN5},{CLTCL1},{DGCR2},{D...             SLC25A1
# 27                    {APPBP2},{BCAS3},{PPM1D},{TBX2}                TBX4
# 28                   {EBF1},{IL12B},{RNF145},{UBLCP1}               IL12B
# 29  {ANKRD52},{APOF},{ATP5F1B},{BAZ2A},{CDK2},{CNP...               IL23A
# 30  {ASCL2},{C11orf21},{CD81},{CTSD},{ENSG00000250...                IGF2
# 31  {AKAP12},{ARMT1},{CCDC170},{ESR1},{RMND1},{SYN...                ESR1
# 32  {ARF5},{FSCN3},{GCC1},{GRM8},{LRRC4},{PAX4},{S...                PAX4
# 33                                          {POU5F1B}               PCAT1
# 34  {ABCC8},{KCNC1},{KCNJ11},{MYOD1},{NCR3LG1},{NU...              KCNJ11
# 35  {AKAP12},{ARMT1},{CCDC170},{ESR1},{RMND1},{SYN...                ESR1
# 36                     {ACADL},{CPS1},{LANCL1},{MYL1}                CPS1
# 37  {ANKK1},{CLDN25},{DRD2},{HTR3A},{HTR3B},{NCAM1...                DRD2
# 38  {DTL},{INTS7},{LPGAT1},{NEK2},{RCOR3},{RD3},{S...              LPGAT1
# 39                   {EBF1},{IL12B},{RNF145},{UBLCP1}               IL12B
# 40  {AMBRA1},{ARFGAP2},{ARHGAP1},{ATG13},{CHRM4},{...                  F2
# 41             {AKTIP},{CHD9},{FTO},{RBL2},{RPGRIP1L}                IRX3
# 42  {ANP32D},{ASB8},{C12orf54},{CCDC184},{COL2A1},...                 VDR
# 43  {EIF5A2},{ENSG00000285218},{RPL22L1},{SLC2A2},...              SLC2A2
# 44  {AGXT2},{BRIX1},{DNAJC21},{PRLR},{RAD1},{RAI14...               AGXT2
# 45  {ABHD1},{AGBL5},{ATRAID},{BABAM2},{C2orf16},{C...                GCKR
# 46  {BEST2},{CACNA1A},{CALR},{DAND5},{DHPS},{DNASE...                GCDH
# 47  {ACSL6},{AFF4},{CCNI2},{CSF2},{ENSG00000281938...                 IL5
# 48  {ARL2BP},{BBS2},{CCL17},{CCL22},{CETP},{CIAPIN...             SLC12A3
# 49  {ABHD1},{ADGRF3},{AGBL5},{CENPA},{CGREF1},{CIB...               KCNK3
#
#    gpt4_pred  gpt4_confidence  \
# 0     CYP7A1              0.9
# 1       TPM1              0.7
# 2       PAX4              0.8
# 3       CPS1              0.9
# 4      HMGCR              0.9
# 5       WFS1              0.9
# 6      IL12B              0.9
# 7    CCDC88A              0.7
# 8      SPTA1              0.7
# 9       LDLR              0.9
# 10      SNCA              0.9
# 11     HMGCR              0.8
# 12     IL12B              0.9
# 13     EDNRA              0.7
# 14     IL12B              0.9
# 15     EDNRA              0.7
# 16  SLC22A12              0.9
# 17     CCND1              0.8
# 18     PROCR              0.7
# 19     WNT16              0.9
# 20     VLDLR              0.9
# 21     HNF1A              0.9
# 22     HERC2              0.7
# 23      GLS2              0.9
# 24   ANGPTL3              0.9
# 25      BMP2              0.7
# 26   SLC25A1              0.8
# 27     BCAS3              0.7
# 28     IL12B              0.9
# 29     IL23A              0.9
# 30     KCNQ1              0.9
# 31      ESR1              0.9
# 32      PAX4              0.9
# 33   POU5F1B              0.8
# 34     ABCC8              0.9
# 35      ESR1              0.9
# 36      CPS1              0.8
# 37      DRD2              0.9
# 38    LPGAT1              0.7
# 39     IL12B              0.9
# 40        F2              0.9
# 41       FTO              0.9
# 42       VDR              0.8
# 43    SLC2A2              0.9
# 44     AGXT2              0.9
# 45      GCKR              0.8
# 46      GCDH              0.9
# 47      IL13              0.9
# 48      CETP              0.7
# 49     KCNK3              0.7
#
#                                           gpt4_reason claude35_pred  \
# 0   CYP7A1 is involved in cholesterol metabolism, ...        CYP7A1
# 1   TPM1 is involved in cardiac muscle contraction...          TPM1
# 2   PAX4 is a known regulator of pancreatic beta c...          PAX4
# 3   CPS1 is directly involved in the urea cycle, w...          CPS1
# 4   HMGCR is directly involved in cholesterol bios...         HMGCR
# 5   WFS1 gene is associated with Wolfram syndrome,...          WFS1
# 6   IL12B is involved in the immune response, and ...         IL12B
# 7   CCDC88A is involved in axon guidance, a critic...         PNPT1
# 8   SPTA1 gene is involved in the production of sp...         SPTA1
# 9   LDLR is directly involved in low-density lipop...          LDLR
# 10  SNCA is directly implicated in Parkinson's dis...          SNCA
# 11  HMGCR is involved in cholesterol biosynthesis,...         HMGCR
# 12  IL12B is involved in the immune response, whic...         IL12B
# 13  EDNRA is involved in cardiovascular system dev...         EDNRA
# 14  IL12B is involved in the immune response, and ...         IL12B
# 15  EDNRA is involved in the regulation of vascula...         EDNRA
# 16  SLC22A12 is associated with uric acid transpor...      SLC22A12
# 17  CCND1 is involved in cell cycle regulation, a ...         CCND1
# 18  PROCR has been associated with lipid metabolis...         PROCR
# 19  WNT16 is associated with bone mineral density ...         WNT16
# 20  VLDLR is involved in cholesterol metabolism, m...         VLDLR
# 21  HNF1A mutations are associated with maturity-o...         HNF1A
# 22  HERC2 is involved in DNA repair and regulation...          OCA2
# 23  GLS2 encodes for Glutaminase 2, an enzyme that...          GLS2
# 24  ANGPTL3 is known to play a crucial role in lip...       ANGPTL3
# 25  BMP2 is involved in bone and cartilage develop...          BMP2
# 26  SLC25A1 encodes a mitochondrial citrate carrie...       SLC25A1
# 27  BCAS3 is associated with bone mineral density ...          TBX2
# 28  IL12B is involved in immune response regulatio...         IL12B
# 29  IL23A is involved in inflammatory responses an...         IL23A
# 30  Multiple studies have identified KCNQ1 as a ge...           INS
# 31  ESR1 encodes estrogen receptor alpha, a key ho...          ESR1
# 32  PAX4 is a known regulator of pancreatic beta c...          PAX4
# 33  POU5F1B is associated with prostate cancer ris...       POU5F1B
# 34  ABCC8 gene mutations are known to cause congen...        KCNJ11
# 35  ESR1 encodes estrogen receptor alpha, a key ho...          ESR1
# 36  CPS1 is involved in the urea cycle, which is c...          CPS1
# 37  DRD2 gene is associated with dopamine neurotra...          DRD2
# 38  LPGAT1 is involved in lipid metabolism, which ...        LPGAT1
# 39  IL12B is involved in immune response regulatio...         IL12B
# 40  F2 gene encodes prothrombin, a key protein in ...            F2
# 41  Multiple studies have identified FTO as a majo...           FTO
# 42  VDR (Vitamin D Receptor) gene has been associa...           VDR
# 43  SLC2A2 encodes GLUT2, a glucose transporter, d...        SLC2A2
# 44  AGXT2 is involved in the metabolism of 3-amino...         AGXT2
# 45  GCKR has been associated with type 2 diabetes ...          GCKR
# 46  GCDH is directly involved in the metabolism of...          GCDH
# 47  IL13 is a well-known gene associated with asth...          IL13
# 48  CETP gene is associated with lipid metabolism,...          CETP
# 49  KCNK3 is involved in potassium ion transport, ...         KCNK3
#
#     claude35_confidence                                    claude35_reason  \
# 0                  0.90  CYP7A1 encodes cholesterol 7-alpha-hydroxylase...
# 1                  0.80  TPM1 encodes tropomyosin, a crucial protein fo...
# 2                  0.90  PAX4 is a transcription factor crucial for pan...
# 3                  0.90  CPS1 encodes carbamoyl phosphate synthetase I,...
# 4                  0.95  HMGCR encodes HMG-CoA reductase, the rate-limi...
# 5                  0.90  WFS1 mutations cause Wolfram syndrome, which i...
# 6                  0.90  IL12B encodes interleukin-12 subunit beta, a c...
# 7                  0.80  PNPT1 mutations are associated with various pe...
# 8                  0.90  SPTA1 encodes spectrin alpha, a key component ...
# 9                  0.90  LDLR encodes the low-density lipoprotein recep...
# 10                 0.95  SNCA encodes alpha-synuclein, a protein that f...
# 11                 0.80  HMGCR encodes HMG-CoA reductase, a key enzyme ...
# 12                 0.90  IL12B encodes interleukin-12 subunit beta, a c...
# 13                 0.80  EDNRA encodes endothelin receptor type A, invo...
# 14                 0.90  IL12B encodes interleukin-12 subunit beta, a c...
# 15                 0.80  EDNRA encodes endothelin receptor type A, invo...
# 16                 0.90  SLC22A12 encodes URAT1, a urate transporter in...
# 17                 0.90  CCND1 encodes cyclin D1, a key regulator of ce...
# 18                 0.80  PROCR encodes protein C receptor, involved in ...
# 19                 0.90  WNT16 is a key regulator of bone mass and stre...
# 20                 0.80  VLDLR (Very Low Density Lipoprotein Receptor) ...
# 21                 0.90  HNF1A is a well-established gene associated wi...
# 22                 0.80  OCA2 is involved in melanin production and pig...
# 23                 0.90  GLS2 encodes glutaminase 2, an enzyme directly...
# 24                 0.90  ANGPTL3 is well-established as a key regulator...
# 25                 0.90  BMP2 is crucial for bone and muscle developmen...
# 26                 0.90  SLC25A1 encodes a mitochondrial citrate transp...
# 27                 0.70  TBX2 is involved in bone development and has b...
# 28                 0.90  IL12B encodes interleukin-12 subunit beta, a c...
# 29                 0.90  IL23A encodes interleukin-23 subunit alpha, a ...
# 30                 0.90  INS encodes insulin, the key hormone regulatin...
# 31                 0.90  ESR1 encodes estrogen receptor alpha, a key re...
# 32                 0.80  PAX4 is a transcription factor crucial for pan...
# 33                 0.70  POU5F1B is a pseudogene of POU5F1, which is in...
# 34                 0.90  KCNJ11 encodes a potassium channel subunit cru...
# 35                 0.90  ESR1 encodes estrogen receptor alpha, a key re...
# 36                 0.90  CPS1 encodes carbamoyl phosphate synthetase I,...
# 37                 0.90  DRD2 encodes dopamine receptor D2, a key targe...
# 38                 0.80  LPGAT1 encodes lysophosphatidylglycerol acyltr...
# 39                 0.90  IL12B encodes interleukin-12 subunit beta, a c...
# 40                 0.90  F2 encodes prothrombin, a key coagulation fact...
# 41                 0.90  FTO is strongly associated with obesity risk. ...
# 42                 0.80  VDR (Vitamin D Receptor) is associated with im...
# 43                 0.90  SLC2A2 encodes GLUT2, a glucose transporter cr...
# 44                 0.90  AGXT2 encodes alanine-glyoxylate aminotransfer...
# 45                 0.90  GCKR encodes glucokinase regulatory protein, w...
# 46                 0.90  GCDH encodes glutaryl-CoA dehydrogenase, which...
# 47                 0.90  IL13 is a key cytokine in asthma and allergic ...
# 48                 0.80  CETP is well-known for its role in lipid metab...
# 49                 0.80  KCNK3 encodes a potassium channel involved in ...
#
#    llama3_pred  llama3_confidence  \
# 0       CYP7A1                0.8
# 1        RAB8B                0.7
# 2         PAX4                0.7
# 3         CPS1                0.8
# 4        HMGCR                0.8
# 5         WFS1                0.8
# 6        IL12B                0.8
# 7       CFAP36                0.8
# 8        IFI16                0.8
# 9         LDLR                0.8
# 10        SNCA                0.9
# 11       HMGCR                0.8
# 12      RNF145                0.8
# 13       EDNRA                0.8
# 14       IL12B                0.8
# 15       EDNRA                0.8
# 16    SLC22A11                0.8
# 17       CCND1                0.8
# 18        CETP                0.8
# 19       CPED1                0.8
# 20       VLDLR                0.8
# 21       HNF1A                0.8
# 22       HERC2                0.7
# 23        GLS2                0.8
# 24     ANGPTL3                0.9
# 25        BMP2                0.8
# 26     SLC25A1                0.8
# 27        TBX2                0.8
# 28      RNF145                0.8
# 29       IL23A                0.8
# 30         INS                0.9
# 31        ESR1                0.8
# 32        PAX4                0.7
# 33     POU5F1B                0.8
# 34       ABCC8                0.9
# 35        ESR1                0.8
# 36        CPS1                0.8
# 37        DRD2                0.8
# 38      LPGAT1                0.8
# 39       IL12B                0.8
# 40          F2                0.8
# 41         FTO                0.8
# 42    HLA-DRB1                0.8
# 43      SLC2A2                0.8
# 44       AGXT2                0.9
# 45        GCKR                0.8
# 46        GCDH                0.8
# 47        IL13                0.7
# 48        CETP                0.8
# 49       AGBL5                0.8
#
#                                         llama3_reason
# 0   CYP7A1 is a well-established enzyme involved i...
# 1   RAB8B has been implicated in cardiac developme...
# 2   PAX4 has been previously implicated in type 2 ...
# 3   CPS1 is the primary enzyme responsible for con...
# 4   HMGCR is a well-established gene involved in c...
# 5   WFS1 has been previously implicated in type 2 ...
# 6   IL12B has been implicated in the pathogenesis ...
# 7   CFAP36 is a peripheral myelin protein involved...
# 8   IFI16 is a known regulator of erythropoiesis a...
# 9   LDLR is a well-established gene involved in LD...
# 10  SNCA is a well-established risk gene for Parki...
# 11  Strong evidence links HMGCR to type 2 diabetes...
# 12  RNF145 has been implicated in the regulation o...
# 13  EDNRA is a well-established regulator of cardi...
# 14  IL12B has been implicated in the pathogenesis ...
# 15  EDNRA is a well-established regulator of cardi...
# 16  SLC22A11 has been previously associated with g...
# 17  CCND1 has been consistently implicated in brea...
# 18  CETP is a well-established gene associated wit...
# 19  CPED1 has been implicated in bone development ...
# 20  VLDLR is a well-established regulator of chole...
# 21  Strong evidence from multiple studies suggests...
# 22  HERC2 has been implicated in skin cancer devel...
# 23  GLS2 is a well-established gene involved in gl...
# 24  ANGPTL3 is a well-established regulator of HDL...
# 25  BMP2 is a key regulator of bone development an...
# 26  SLC25A1 is a citrate transporter and has been ...
# 27  TBX2 has been implicated in regulating bone de...
# 28  RNF145 has been implicated in the regulation o...
# 29  Strong association with psoriasis in multiple ...
# 30  Insulin (INS) is a well-established risk facto...
# 31  Strong evidence from multiple studies suggests...
# 32  PAX4 is a transcription factor involved in pan...
# 33  POU5F1B has been implicated in prostate cancer...
# 34  Strong evidence links ABCC8 to type 2 diabetes...
# 35  Strong evidence from multiple studies suggests...
# 36  CPS1 is the primary enzyme responsible for con...
# 37  Previous studies have implicated DRD2 in schiz...
# 38  LPGAT1 is a lipase involved in triglyceride hy...
# 39  IL12B has been implicated in the pathogenesis ...
# 40  F2 is a well-established risk factor for DVT, ...
# 41  FTO has been consistently associated with obes...
# 42  Strong association with rheumatoid arthritis a...
# 43  SLC2A2 is a well-established glucose transport...
# 44  AGXT2 is the primary enzyme responsible for th...
# 45  Strong association with type 2 diabetes risk a...
# 46  GCDH is a key enzyme involved in the metabolis...
# 47  IL13 is a well-established cytokine involved i...
# 48  CETP has been consistently associated with car...
# 49  AGBL5 has been implicated in hypertension thro...

# %%
open_target_results_df.iloc[41]["claude35_reason"]
# Out:
# 'FTO is strongly associated with obesity risk. It regulates energy homeostasis and adipocyte differentiation. Variants in FTO are consistently linked to increased BMI and obesity in multiple populations.'

# %%
open_target_results_df.to_csv("/mnt/hdd_2/abdu/llm_exp/open_targets_results_llms.csv", index=False) 
# open_target_results_df = pd.read_csv("/mnt/hdd_2/abdu/llm_exp/open_targets_results_llms.csv")
open_target_results_df.tail()
# Out:
#                                        GWAS Phenotype  \
# 95  Disorders of lipoid metabolism (Disorder of li...
# 96  treatment with nicorandil (coronary artery dis...
# 97        Type 2 diabetes (type II diabetes mellitus)
# 98        Type 2 diabetes (type II diabetes mellitus)
# 99                        Fasting Glucose (D-Glucose)
#
#                                                 Genes ground_truth_symbol  \
# 95  {ACOT11},{BSND},{DHCR24},{FAM151A},{LEXM},{MRO...               PCSK9
# 96                  {CDKN2A},{CDKN2B},{DMRTA1},{MTAP}              CDKN2B
# 97                   {ANKH},{OTULIN},{OTULINL},{TRIO}                ANKH
# 98  {AK3},{CDC37L1},{GLIS3},{PLPP6},{SLC1A1},{SPAT...               GLIS3
# 99  {AEBP1},{BLVRA},{CAMK2B},{COA1},{DBNL},{DDX56}...                 GCK
#
#    gpt4_pred  gpt4_confidence  \
# 95     PCSK9              0.9
# 96    CDKN2A              0.7
# 97      ANKH              0.7
# 98     GLIS3              0.9
# 99       GCK              0.9
#
#                                           gpt4_reason claude35_pred  \
# 95  PCSK9 is well-documented in literature for its...         PCSK9
# 96  CDKN2A is associated with coronary artery dise...        CDKN2B
# 97  ANKH gene is associated with type 2 diabetes t...          ANKH
# 98  Multiple studies have identified GLIS3 as a ge...         GLIS3
# 99  GCK (Glucokinase) is a key regulator of glucos...           GCK
#
#     claude35_confidence                                    claude35_reason  \
# 95                  0.9  PCSK9 is well-known to regulate LDL cholestero...
# 96                  0.8  CDKN2B is associated with coronary artery dise...
# 97                  0.7  ANKH regulates pyrophosphate levels, which are...
# 98                  0.9  GLIS3 is a transcription factor involved in pa...
# 99                  0.9  GCK (Glucokinase) is a key enzyme in glucose m...
#
#    llama3_pred  llama3_confidence  \
# 95       PCSK9                0.8
# 96      CDKN2A                0.8
# 97        ANKH                0.8
# 98       GLIS3                0.8
# 99         GCK                0.8
#
#                                         llama3_reason
# 95  PCSK9 is a well-established gene involved in l...
# 96  CDKN2A is a well-established regulator of cell...
# 97  ANKH has been previously implicated in type 2 ...
# 98  GLIS3 has been previously implicated in type 2...
# 99  GCK is a well-established gene involved in glu...

# %%
gwas_catalog_results, gwas_catalog_gpt4_pred, gwas_catalog_claude35_pred, \
    gwas_catalog_llama3_pred = evaluate_llm_on_benchmark(seed, gwas_catalog_df)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 100/100 [09:40<00:00,  5.80s/it]

# %%
n_hallucination_gpt4 = sum([1 for p in gwas_catalog_gpt4_pred if p == -1])
n_correct_gpt4 = sum([1 for p in gwas_catalog_gpt4_pred if p == 1])
n_incorrect_gpt4 = sum([1 for p in gwas_catalog_gpt4_pred if p == 0])

n_hallucination_claud35 = sum([1 for p in gwas_catalog_claude35_pred if p == -1])
n_correct_claud35 = sum([1 for p in gwas_catalog_claude35_pred if p == 1])
n_incorrect_claud35 = sum([1 for p in gwas_catalog_claude35_pred if p == 0])

n_hallucination_llama3 = sum([1 for p in gwas_catalog_llama3_pred if p == -1])
n_correct_llama3 = sum([1 for p in gwas_catalog_llama3_pred if p == 1])
n_incorrect_llama3 = sum([1 for p in gwas_catalog_llama3_pred if p == 0])

print(f"GWAS Catalog: GPT-4 hallucination: {n_hallucination_gpt4}, correct: {n_correct_gpt4}, incorrect: {n_incorrect_gpt4}")
print(f"GWAS Catalog: Claude3.5 hallucination: {n_hallucination_claud35}, correct: {n_correct_claud35}, incorrect: {n_incorrect_claud35}")
print(f"GWAS Catalog: Llama3 hallucination: {n_hallucination_llama3}, correct: {n_correct_llama3}, incorrect: {n_incorrect_llama3}")
# Out:
# GWAS Catalog: GPT-4 hallucination: 0, correct: 62, incorrect: 38
# GWAS Catalog: Claude3.5 hallucination: 0, correct: 69, incorrect: 31
# GWAS Catalog: Llama3 hallucination: 2, correct: 26, incorrect: 72

# %%
gpt4_precision = n_correct_gpt4 / (n_correct_gpt4 + n_incorrect_gpt4)
gpt4_recall = n_correct_gpt4 / (n_correct_gpt4 + n_hallucination_gpt4 + n_incorrect_gpt4)

claude35_precision = n_correct_claud35 / (n_correct_claud35 + n_incorrect_claud35)
claude35_recall = n_correct_claud35 / (n_correct_claud35 + n_hallucination_claud35 + n_incorrect_claud35)

llama3_precision = n_correct_llama3 / (n_correct_llama3 + n_incorrect_llama3)
llama3_recall = n_correct_llama3 / (n_correct_llama3 + n_hallucination_llama3 + n_incorrect_llama3)

gpt4_f1 = 2 * (gpt4_precision * gpt4_recall) / (gpt4_precision + gpt4_recall)
claude35_f1 = 2 * (claude35_precision * claude35_recall) / (claude35_precision + claude35_recall)
llama3_f1 = 2 * (llama3_precision * llama3_recall) / (llama3_precision + llama3_recall)

print(f"GWAS Catalog: GPT-4 precision: {gpt4_precision}, recall: {gpt4_recall}, F1: {gpt4_f1}")
print(f"GWAS Catalog: Claude3.5 precision: {claude35_precision}, recall: {claude35_recall}, F1: {claude35_f1}")
print(f"GWAS Catalog: Llama3 precision: {llama3_precision}, recall: {llama3_recall}, F1: {llama3_f1}")
# Out:
# GWAS Catalog: GPT-4 precision: 0.62, recall: 0.62, F1: 0.62
# GWAS Catalog: Claude3.5 precision: 0.69, recall: 0.69, F1: 0.69
# GWAS Catalog: Llama3 precision: 0.2653061224489796, recall: 0.26, F1: 0.2626262626262626

# %%
gwas_catalog_results_df = pd.DataFrame(gwas_catalog_results)
gwas_catalog_results_df.to_csv("/mnt/hdd_2/abdu/llm_exp/gwas_catalog_results_llms.csv", index=False)
# gwas_catalog_results_df = pd.read_csv("/mnt/hdd_2/abdu/llm_exp/gwas_catalog_results_llms.csv")
gwas_catalog_results_df.tail()
# Out:
#                                        GWAS Phenotype  \
# 95                              Multi-trait sex score
# 96  Metabolite levels (N-acetylglucosaminylasparag...
# 97                              Multi-trait sex score
# 98  Metabolite levels (propyl 4-hydroxybenzoate su...
# 99  Metabolite levels (cysteine-glutathione disulf...
#
#                                                 Genes ground_truth_symbol  \
# 95  {ATP6V1B2},{CSGALNACT1},{INTS10},{LPL},{LZTS1}...                 LPL
# 96  {CCR6},{CEP43},{ENSG00000249141},{ENSG00000272...              UNC93A
# 97  {ATP6V1B2},{CSGALNACT1},{INTS10},{LPL},{LZTS1}...                 LPL
# 98  {APOBR},{ATP2A1},{ATXN2L},{CD19},{CLN3},{EIF3C...             SULT1A1
# 99  {ADORA2A},{CABIN1},{ENSG00000286070},{GGT1},{G...                GGT1
#
#    gpt4_pred  gpt4_confidence  \
# 95       LPL              0.7
# 96   RPS6KA2              0.7
# 97       LPL              0.7
# 98   SULT1A1              0.8
# 99      GGT1              0.9
#
#                                           gpt4_reason claude35_pred  \
# 95  LPL gene is associated with lipid metabolism a...           LPL
# 96  RPS6KA2 is involved in the regulation of cellu...       RNASET2
# 97  LPL gene is associated with lipid metabolism a...           LPL
# 98  SULT1A1 is involved in the sulfation and metab...       SULT1A1
# 99  GGT1 is directly involved in glutathione metab...          GGT1
#
#     claude35_confidence                                    claude35_reason  \
# 95                  0.8  LPL encodes lipoprotein lipase, which plays a ...
# 96                  0.7  RNASET2 is involved in RNA metabolism and cell...
# 97                  0.7  LPL encodes lipoprotein lipase, involved in li...
# 98                  0.9  SULT1A1 encodes a sulfotransferase enzyme invo...
# 99                  0.9  GGT1 encodes gamma-glutamyltransferase 1, an e...
#
#         llama3_pred  llama3_confidence  \
# 95       CSGALNACT1                0.8
# 96  ENSG00...002790                0.8
# 97       CSGALNACT1                0.8
# 98          SULT1A1                0.8
# 99             GGT1                0.8
#
#                                         llama3_reason
# 95  CSGALNACT1 is a known sex-determining gene in ...
# 96  Previous studies have linked GPR31 to the regu...
# 97  CSGALNACT1 is a known sex-determining gene in ...
# 98  Sulfotransferase enzymes, including SULT1A1, a...
# 99  GGT1 is a well-established enzyme responsible ...

# %%
gwas_catalog_gpt4_miss = gwas_catalog_results_df[gwas_catalog_results_df["ground_truth_symbol"] != gwas_catalog_results_df["gpt4_pred"]]
gwas_catalog_gpt4_miss
# for idx, row in gwas_gpt4_miss.iterrows():
#     print(f"GWAS Phenotype: {row['GWAS Phenotype']}")
#     print(f"Genes: {row['Genes']}")
#     print(f"Ground Truth: {row['ground_truth_symbol']}")
#     print(f"GPT-4 Prediction: {row['gpt4_pred']}")
#     print(f"GPT-4 Confidence: {row['gpt4_confidence']}")
#     print(f"GPT-4 Reason: {row['gpt4_reason']}")
#     print(f"Llama3 Prediction: {row['llama3_pred']}")
#     print(f"Llama3 Confidence: {row['llama3_confidence']}")
#     print(f"Llama3 Reason: {row['llama3_reason']}")
#     print("\n")
# Out:
#                                        GWAS Phenotype  \
# 5                               Multi-trait sex score
# 7                               Multi-trait sex score
# 9                               Multi-trait sex score
# 16              Triglyceride to HDL cholesterol ratio
# 18                    Anterior amygdaloid area volume
# 19                              Multi-trait sex score
# 20              Triglyceride to HDL cholesterol ratio
# 23                                    Body mass index
# 24                              Multi-trait sex score
# 27                              Medial nucleus volume
# 31  COVID-19 hospitalization or osteoarthritis (MTAG)
# 32                              Multi-trait sex score
# 34  Primary open angle glaucoma (multi-trait analy...
# 36        Metabolite levels (Fibrinopeptide A (8-16))
# 40  Neonatal circulating Complement Component 4 (C...
# 41                              Multi-trait sex score
# 42                      Metabolite levels (aspartate)
# 47                              Multi-trait sex score
# 48                Metabolite levels (N6-methyllysine)
# 53  Neonatal circulating Complement Component 4 (C...
# 55                              Multi-trait sex score
# 56                              Multi-trait sex score
# 58                              Multi-trait sum score
# 60                             Central nucleus volume
# 61                              Multi-trait sex score
# 62                              Multi-trait sex score
# 63                 Metabolite levels (indolebutyrate)
# 64                              Multi-trait sex score
# 65                              Multi-trait sex score
# 66                              Multi-trait sex score
# 71                              Multi-trait sex score
# 75                              Multi-trait sum score
# 85             Metabolite levels (N-acetyltryptophan)
# 86  Neonatal circulating Complement Component 4 (C...
# 89                              Multi-trait sex score
# 91                              Multi-trait sum score
# 94  COVID-19 hospitalization or osteoarthritis (MTAG)
# 96  Metabolite levels (N-acetylglucosaminylasparag...
#
#                                                 Genes ground_truth_symbol  \
# 5   {APOA1},{APOA4},{APOA5},{APOC3},{BUD13},{PAFAH...               APOA4
# 7   {ANKRD29},{CABLES1},{LAMA3},{NPC1},{RBBP8},{RI...             TMEM241
# 9   {ARL2BP},{BBS2},{CCL17},{CCL22},{CETP},{CIAPIN...                CETP
# 16  {APOA1},{APOA4},{APOA5},{APOC3},{BACE1},{BUD13...              CEP164
# 18                  {BANK1},{MANBA},{NFKB1},{SLC39A8}             SLC39A8
# 19  {BMP8A},{BMP8B},{CAP1},{HEYL},{HPCAL4},{MACF1}...               MACF1
# 20  {IGF2R},{LPA},{MAP3K4},{PLG},{SLC22A1},{SLC22A...             SLC22A1
# 23  {CACNA1D},{DCP1A},{ENSG00000243696},{ENSG00000...               ITIH3
# 24  {ADAP2},{ATAD5},{BLMH},{CPD},{CRLF3},{GOSR1},{...               ATAD5
# 27                         {BANK1},{PPP3CA},{SLC39A8}             SLC39A8
# 31  {CCR1},{CCR2},{CCR3},{CCR5},{CCR9},{CCRL2},{CX...               FYCO1
# 32  {APOA1},{APOA4},{APOA5},{APOC3},{BUD13},{PAFAH...               APOA4
# 34  {CFAP52},{DHRS7C},{GAS7},{GLP2R},{GSG1L2},{MYH...               MYH13
# 36                     {EGF},{ELOVL6},{ENPEP},{PITX2}               ENPEP
# 40  {AGER},{AGPAT1},{ATF6B},{BTNL2},{C2},{C4A},{C4...              NOTCH4
# 41  {APOA1},{APOA4},{APOA5},{APOC3},{BUD13},{PAFAH...               APOA4
# 42                     {EGF},{ELOVL6},{ENPEP},{PITX2}               ENPEP
# 47  {ARL2BP},{BBS2},{CCL17},{CCL22},{CETP},{CIAPIN...                CETP
# 48  {CRTAC1},{ENSG00000289758},{HPS1},{HPSE2},{LOX...             PYROXD2
# 53  {ABHD16A},{AIF1},{APOM},{ATF6B},{ATP6V1G2},{AT...              ZBTB12
# 55  {APOA1},{APOA4},{APOA5},{APOC3},{BUD13},{SIK3}...               APOA4
# 56  {CABLES1},{NPC1},{RBBP8},{RIOK3},{RMC1},{TMEM241}             TMEM241
# 58  {BABAM2},{C2orf16},{CCDC121},{DNAJC5G},{EIF2B4...              TRIM54
# 60                         {BANK1},{PPP3CA},{SLC39A8}             SLC39A8
# 61  {APOA1},{APOA4},{APOA5},{APOC3},{BUD13},{PAFAH...               APOA4
# 62  {APOA1},{APOA4},{APOA5},{APOC3},{BACE1},{BUD13...               APOA4
# 63  {ACSM1},{ACSM2A},{ACSM2B},{ACSM3},{ACSM5},{DCU...              ACSM2A
# 64  {ACTL9},{ADAMTS10},{ANGPTL4},{CD320},{CERS4},{...               PRAM1
# 65  {APOA1},{APOA4},{APOA5},{APOC3},{BUD13},{PAFAH...               APOA4
# 66  {ACADVL},{ACAP1},{ALOX12B},{ALOX15B},{ALOXE3},...               ZBTB4
# 71  {APOA1},{APOA4},{APOA5},{APOC3},{BUD13},{PAFAH...               APOA4
# 75  {ABHD1},{AGBL5},{ATRAID},{C2orf16},{CAD},{CCDC...              TRIM54
# 85  {ACY3},{AIP},{ALDH3B1},{ALDH3B2},{ANKRD13D},{C...                ACY3
# 86  {ABHD16A},{AGER},{AGPAT1},{AIF1},{APOM},{ATF6B...                TNXB
# 89  {ADAP2},{ATAD5},{CPD},{CRLF3},{ENSG00000265118...               ATAD5
# 91  {ABHD1},{AGBL5},{ATRAID},{BABAM2},{C2orf16},{C...              TRIM54
# 94  {ALS2CL},{CCR1},{CCR2},{CCR3},{CCR5},{CCR9},{C...               FYCO1
# 96  {CCR6},{CEP43},{ENSG00000249141},{ENSG00000272...              UNC93A
#
#    gpt4_pred  gpt4_confidence  \
# 5      APOA5              0.7
# 7       NPC1              0.7
# 9     ARL2BP              0.7
# 16     APOA5              0.9
# 18     NFKB1              0.7
# 19     BMP8B              0.7
# 20       LPA              0.8
# 23   CACNA1D              0.7
# 24    SLC6A4              0.7
# 27    PPP3CA              0.7
# 31      CCR5              0.8
# 32     APOA1              0.7
# 34      MYH1              0.7
# 36     PITX2              0.7
# 40       C4A              0.9
# 41     APOA5              0.7
# 42    ELOVL6              0.7
# 47    ARL2BP              0.7
# 48    CRTAC1              0.7
# 53       C4A              0.9
# 55     APOA5              0.7
# 56      NPC1              0.7
# 58      GCKR              0.7
# 60    PPP3CA              0.7
# 61     APOA5              0.7
# 62     APOA5              0.7
# 63    ACSM2B              0.7
# 64  ADAMTS10              0.7
# 65     APOA5              0.7
# 66      SHBG              0.8
# 71     APOA5              0.7
# 75      GCKR              0.7
# 85    NDUFS8              0.7
# 86       C4A              0.9
# 89       NF1              0.7
# 91      GCKR              0.7
# 94      CCR5              0.8
# 96   RPS6KA2              0.7
#
#                                           gpt4_reason claude35_pred  \
# 5   APOA5 is associated with lipid metabolism and ...         APOA5
# 7   NPC1 gene is associated with lipid metabolism ...          NPC1
# 9   ARL2BP is involved in sex determination and di...          CETP
# 16  APOA5 is directly involved in triglyceride met...         APOA5
# 18  NFKB1 is involved in neurodevelopment and neur...       SLC39A8
# 19  BMP8B is involved in reproductive processes an...        MFSD2A
# 20  LPA gene is associated with lipid metabolism a...           LPA
# 23  CACNA1D is involved in calcium signaling, whic...         PRKCD
# 24  SLC6A4 is involved in the regulation of neurot...        SLC6A4
# 27  PPP3CA is involved in neurodevelopment and syn...       SLC39A8
# 31  CCR5 has been implicated in COVID-19 severity ...          CCR5
# 32  APOA1 is involved in lipid metabolism and has ...         APOA5
# 34  MYH1 has been implicated in eye muscle develop...          GAS7
# 36  PITX2 is involved in several metabolic process...         ENPEP
# 40  C4A is directly involved in the complement sys...           C4A
# 41  APOA5 is associated with lipid metabolism and ...         APOA5
# 42  ELOVL6 is involved in the metabolism of fatty ...         ENPEP
# 47  ARL2BP is involved in sex determination and di...          CETP
# 48  CRTAC1 is involved in amino acid metabolism an...       PYROXD2
# 53  C4A is directly involved in the complement sys...           C4A
# 55  APOA5 is associated with lipid metabolism and ...         APOA5
# 56  NPC1 gene is associated with lipid metabolism ...          NPC1
# 58  GCKR has been associated with metabolic traits...          GCKR
# 60  PPP3CA is involved in calcium-dependent signal...       SLC39A8
# 61  APOA5 is associated with lipid metabolism and ...         APOA5
# 62  APOA5 is associated with lipid metabolism and ...         APOA5
# 63  ACSM2B is involved in the metabolism of short-...        ACSM2A
# 64  ADAMTS10 is involved in connective tissue stru...        MBD3L1
# 65  APOA5 is associated with lipid metabolism and ...         APOA5
# 66  SHBG (Sex Hormone-Binding Globulin) is directl...          SHBG
# 71  APOA5 is associated with lipid metabolism and ...         APOA5
# 75  GCKR has been associated with metabolic traits...          GCKR
# 85  NDUFS8 is involved in the mitochondrial respir...        CARNS1
# 86  C4A gene is directly involved in the productio...           C4A
# 89  NF1 is known to be involved in multiple traits...           NF1
# 91  GCKR has been associated with metabolic traits...          GCKR
# 94  CCR5 is involved in immune response and has be...          CCR5
# 96  RPS6KA2 is involved in the regulation of cellu...       RNASET2
#
#     claude35_confidence                                    claude35_reason  \
# 5                   0.8  APOA5 is involved in lipid metabolism and has ...
# 7                   0.8  NPC1 is involved in cholesterol trafficking an...
# 9                   0.8  CETP (Cholesteryl Ester Transfer Protein) is s...
# 16                  0.9  APOA5 is strongly associated with triglyceride...
# 18                  0.7  SLC39A8 is involved in zinc transport and has ...
# 19                  0.7  MFSD2A is involved in lipid transport and meta...
# 20                  0.9  LPA encodes lipoprotein(a), strongly associate...
# 23                  0.7  PRKCD encodes protein kinase C delta, involved...
# 24                  0.8  SLC6A4 encodes the serotonin transporter, whic...
# 27                  0.7  SLC39A8 is involved in metal ion transport and...
# 31                  0.8  CCR5 is involved in immune response and has be...
# 32                  0.8  APOA5 is involved in lipid metabolism and has ...
# 34                  0.8  GAS7 is associated with intraocular pressure r...
# 36                  0.7  ENPEP encodes aminopeptidase A, involved in pe...
# 40                  0.9  C4A directly encodes Complement Component 4, t...
# 41                  0.8  APOA5 is strongly associated with lipid metabo...
# 42                  0.8  ENPEP encodes aminopeptidase A, which catalyze...
# 47                  0.8  CETP (Cholesteryl Ester Transfer Protein) is s...
# 48                  0.8  PYROXD2 is involved in metabolic processes and...
# 53                  0.9  C4A directly encodes Complement Component 4, t...
# 55                  0.8  APOA5 is involved in lipid metabolism and has ...
# 56                  0.8  NPC1 is involved in cholesterol trafficking an...
# 58                  0.8  GCKR is a well-known regulator of glucose meta...
# 60                  0.7  SLC39A8 encodes a zinc transporter involved in...
# 61                  0.8  APOA5 is involved in lipid metabolism and has ...
# 62                  0.8  APOA5 is involved in lipid metabolism and has ...
# 63                  0.8  ACSM2A encodes an acyl-CoA synthetase involved...
# 64                  0.7  MBD3L1 is involved in epigenetic regulation an...
# 65                  0.8  APOA5 is involved in lipid metabolism and has ...
# 66                  0.9  SHBG (Sex Hormone-Binding Globulin) is directl...
# 71                  0.8  APOA5 is involved in lipid metabolism and has ...
# 75                  0.8  GCKR is a well-known regulator of glucose and ...
# 85                  0.8  CARNS1 encodes carnosine synthase 1, involved ...
# 86                  0.9  C4A directly encodes Complement Component 4, t...
# 89                  0.8  NF1 is associated with neurofibromatosis type ...
# 91                  0.8  GCKR is a well-known regulator of glucose and ...
# 94                  0.8  CCR5 is involved in immune response and has be...
# 96                  0.7  RNASET2 is involved in RNA metabolism and cell...
#
#         llama3_pred  llama3_confidence  \
# 5             APOA4                0.8
# 7           ANKRD29                0.7
# 9            ARL2BP                0.8
# 16            APOA1                0.8
# 18            BANK1                0.9
# 19            BMP8A                0.7
# 20              LPA                0.8
# 23          CACNA1D                0.8
# 24            ADAP2                0.8
# 27            BANK1                0.9
# 31             CCR5                0.8
# 32             ZPR1                0.8
# 34             GAS7                0.6
# 36           ELOVL6                0.7
# 40              C4A                0.8
# 41            APOA4                0.8
# 42            ENPEP                0.8
# 47           ARL2BP                0.8
# 48            LOXL4                0.8
# 53              C4A                0.8
# 55            APOA4                0.8
# 56            RBBP8                0.7
# 58             GCKR                0.8
# 60            BANK1                0.9
# 61            APOA4                0.8
# 62            BACE1                0.8
# 63            ACSM1                0.8
# 64            ACTL9                0.8
# 65            APOA4                0.8
# 66            DNAH2                0.8
# 71            APOA4                0.8
# 75           ATRAID                0.8
# 85            GSTP1                0.8
# 86              C4A                0.8
# 89            EVI2A                0.8
# 91           ATRAID                0.8
# 94             CCR5                0.8
# 96  ENSG00...002790                0.8
#
#                                         llama3_reason
# 5   APOA4 has been implicated in sex determination...
# 7   ANKRD29 has been implicated in sex determinati...
# 9   ARL2BP has been implicated in sex determinatio...
# 16  APOA1 is a well-established regulator of trigl...
# 18  BANK1 has been implicated in the development a...
# 19  BMP8A has been implicated in sex determination...
# 20  Strong association with triglyceride levels an...
# 23  CACNA1D has been implicated in obesity and met...
# 24  ADAP2 has been implicated in sex-specific gene...
# 27  BANK1 has been implicated in neurodevelopmenta...
# 31  As a chemokine receptor, CCR5 has been implica...
# 32  ZPR1 has been implicated in sex determination ...
# 34  GAS7 has been implicated in the regulation of ...
# 36  ELOVL6 is involved in the regulation of lipid ...
# 40  Strong association with C4 protein concentrati...
# 41  APOA4 has been implicated in sex determination...
# 42  ENPEP is a key enzyme involved in aspartate me...
# 47  ARL2BP has been implicated in sex determinatio...
# 48  LOXL4 is a lysyl oxidase that plays a crucial ...
# 53  Strong association with C4 protein concentrati...
# 55  APOA4 has been implicated in sex determination...
# 56  RBBP8 has been implicated in sex determination...
# 58  GCKR has been previously associated with metab...
# 60  BANK1 has been implicated in neurodevelopmenta...
# 61  APOA4 has been implicated in sex determination...
# 62  BACE1 has been implicated in sex determination...
# 63  ACSM1 is a key enzyme involved in the metaboli...
# 64  ACTL9 has been implicated in sex determination...
# 65  APOA4 has been implicated in sex determination...
# 66  DNAH2 has been implicated in sex determination...
# 71  APOA4 has been implicated in sex determination...
# 75  ATRAID has been implicated in the regulation o...
# 85  GSTP1 is a glutathione S-transferase involved ...
# 86  Strong association with C4 protein concentrati...
# 89  EVI2A has been implicated in sex determination...
# 91  ATRAID has been implicated in the regulation o...
# 94  Previous studies have implicated CCR5 in COVID...
# 96  Previous studies have linked GPR31 to the regu...

# %%
gwas_catalog_claude35_miss = gwas_catalog_results_df[gwas_catalog_results_df["ground_truth_symbol"] != gwas_catalog_results_df["claude35_pred"]]
gwas_catalog_claude35_miss
# Out:
#                                        GWAS Phenotype  \
# 5                               Multi-trait sex score
# 7                               Multi-trait sex score
# 16              Triglyceride to HDL cholesterol ratio
# 19                              Multi-trait sex score
# 20              Triglyceride to HDL cholesterol ratio
# 23                                    Body mass index
# 24                              Multi-trait sex score
# 31  COVID-19 hospitalization or osteoarthritis (MTAG)
# 32                              Multi-trait sex score
# 34  Primary open angle glaucoma (multi-trait analy...
# 40  Neonatal circulating Complement Component 4 (C...
# 41                              Multi-trait sex score
# 49         Neutrophil side scatter distribution width
# 53  Neonatal circulating Complement Component 4 (C...
# 55                              Multi-trait sex score
# 56                              Multi-trait sex score
# 58                              Multi-trait sum score
# 61                              Multi-trait sex score
# 62                              Multi-trait sex score
# 64                              Multi-trait sex score
# 65                              Multi-trait sex score
# 66                              Multi-trait sex score
# 71                              Multi-trait sex score
# 75                              Multi-trait sum score
# 85             Metabolite levels (N-acetyltryptophan)
# 86  Neonatal circulating Complement Component 4 (C...
# 88                              Multi-trait sex score
# 89                              Multi-trait sex score
# 91                              Multi-trait sum score
# 94  COVID-19 hospitalization or osteoarthritis (MTAG)
# 96  Metabolite levels (N-acetylglucosaminylasparag...
#
#                                                 Genes ground_truth_symbol  \
# 5   {APOA1},{APOA4},{APOA5},{APOC3},{BUD13},{PAFAH...               APOA4
# 7   {ANKRD29},{CABLES1},{LAMA3},{NPC1},{RBBP8},{RI...             TMEM241
# 16  {APOA1},{APOA4},{APOA5},{APOC3},{BACE1},{BUD13...              CEP164
# 19  {BMP8A},{BMP8B},{CAP1},{HEYL},{HPCAL4},{MACF1}...               MACF1
# 20  {IGF2R},{LPA},{MAP3K4},{PLG},{SLC22A1},{SLC22A...             SLC22A1
# 23  {CACNA1D},{DCP1A},{ENSG00000243696},{ENSG00000...               ITIH3
# 24  {ADAP2},{ATAD5},{BLMH},{CPD},{CRLF3},{GOSR1},{...               ATAD5
# 31  {CCR1},{CCR2},{CCR3},{CCR5},{CCR9},{CCRL2},{CX...               FYCO1
# 32  {APOA1},{APOA4},{APOA5},{APOC3},{BUD13},{PAFAH...               APOA4
# 34  {CFAP52},{DHRS7C},{GAS7},{GLP2R},{GSG1L2},{MYH...               MYH13
# 40  {AGER},{AGPAT1},{ATF6B},{BTNL2},{C2},{C4A},{C4...              NOTCH4
# 41  {APOA1},{APOA4},{APOA5},{APOC3},{BUD13},{PAFAH...               APOA4
# 49  {CACNG6},{CACNG7},{CACNG8},{CNOT3},{DPRX},{LEN...              NLRP12
# 53  {ABHD16A},{AIF1},{APOM},{ATF6B},{ATP6V1G2},{AT...              ZBTB12
# 55  {APOA1},{APOA4},{APOA5},{APOC3},{BUD13},{SIK3}...               APOA4
# 56  {CABLES1},{NPC1},{RBBP8},{RIOK3},{RMC1},{TMEM241}             TMEM241
# 58  {BABAM2},{C2orf16},{CCDC121},{DNAJC5G},{EIF2B4...              TRIM54
# 61  {APOA1},{APOA4},{APOA5},{APOC3},{BUD13},{PAFAH...               APOA4
# 62  {APOA1},{APOA4},{APOA5},{APOC3},{BACE1},{BUD13...               APOA4
# 64  {ACTL9},{ADAMTS10},{ANGPTL4},{CD320},{CERS4},{...               PRAM1
# 65  {APOA1},{APOA4},{APOA5},{APOC3},{BUD13},{PAFAH...               APOA4
# 66  {ACADVL},{ACAP1},{ALOX12B},{ALOX15B},{ALOXE3},...               ZBTB4
# 71  {APOA1},{APOA4},{APOA5},{APOC3},{BUD13},{PAFAH...               APOA4
# 75  {ABHD1},{AGBL5},{ATRAID},{C2orf16},{CAD},{CCDC...              TRIM54
# 85  {ACY3},{AIP},{ALDH3B1},{ALDH3B2},{ANKRD13D},{C...                ACY3
# 86  {ABHD16A},{AGER},{AGPAT1},{AIF1},{APOM},{ATF6B...                TNXB
# 88  {ACTL9},{ADAMTS10},{ANGPTL4},{CCL25},{CD320},{...             ANGPTL4
# 89  {ADAP2},{ATAD5},{CPD},{CRLF3},{ENSG00000265118...               ATAD5
# 91  {ABHD1},{AGBL5},{ATRAID},{BABAM2},{C2orf16},{C...              TRIM54
# 94  {ALS2CL},{CCR1},{CCR2},{CCR3},{CCR5},{CCR9},{C...               FYCO1
# 96  {CCR6},{CEP43},{ENSG00000249141},{ENSG00000272...              UNC93A
#
#    gpt4_pred  gpt4_confidence  \
# 5      APOA5              0.7
# 7       NPC1              0.7
# 16     APOA5              0.9
# 19     BMP8B              0.7
# 20       LPA              0.8
# 23   CACNA1D              0.7
# 24    SLC6A4              0.7
# 31      CCR5              0.8
# 32     APOA1              0.7
# 34      MYH1              0.7
# 40       C4A              0.9
# 41     APOA5              0.7
# 49    NLRP12              0.7
# 53       C4A              0.9
# 55     APOA5              0.7
# 56      NPC1              0.7
# 58      GCKR              0.7
# 61     APOA5              0.7
# 62     APOA5              0.7
# 64  ADAMTS10              0.7
# 65     APOA5              0.7
# 66      SHBG              0.8
# 71     APOA5              0.7
# 75      GCKR              0.7
# 85    NDUFS8              0.7
# 86       C4A              0.9
# 88   ANGPTL4              0.7
# 89       NF1              0.7
# 91      GCKR              0.7
# 94      CCR5              0.8
# 96   RPS6KA2              0.7
#
#                                           gpt4_reason claude35_pred  \
# 5   APOA5 is associated with lipid metabolism and ...         APOA5
# 7   NPC1 gene is associated with lipid metabolism ...          NPC1
# 16  APOA5 is directly involved in triglyceride met...         APOA5
# 19  BMP8B is involved in reproductive processes an...        MFSD2A
# 20  LPA gene is associated with lipid metabolism a...           LPA
# 23  CACNA1D is involved in calcium signaling, whic...         PRKCD
# 24  SLC6A4 is involved in the regulation of neurot...        SLC6A4
# 31  CCR5 has been implicated in COVID-19 severity ...          CCR5
# 32  APOA1 is involved in lipid metabolism and has ...         APOA5
# 34  MYH1 has been implicated in eye muscle develop...          GAS7
# 40  C4A is directly involved in the complement sys...           C4A
# 41  APOA5 is associated with lipid metabolism and ...         APOA5
# 49  NLRP12 is involved in the regulation of inflam...        LILRA5
# 53  C4A is directly involved in the complement sys...           C4A
# 55  APOA5 is associated with lipid metabolism and ...         APOA5
# 56  NPC1 gene is associated with lipid metabolism ...          NPC1
# 58  GCKR has been associated with metabolic traits...          GCKR
# 61  APOA5 is associated with lipid metabolism and ...         APOA5
# 62  APOA5 is associated with lipid metabolism and ...         APOA5
# 64  ADAMTS10 is involved in connective tissue stru...        MBD3L1
# 65  APOA5 is associated with lipid metabolism and ...         APOA5
# 66  SHBG (Sex Hormone-Binding Globulin) is directl...          SHBG
# 71  APOA5 is associated with lipid metabolism and ...         APOA5
# 75  GCKR has been associated with metabolic traits...          GCKR
# 85  NDUFS8 is involved in the mitochondrial respir...        CARNS1
# 86  C4A gene is directly involved in the productio...           C4A
# 88  ANGPTL4 is involved in lipid metabolism and ha...       TGFBR3L
# 89  NF1 is known to be involved in multiple traits...           NF1
# 91  GCKR has been associated with metabolic traits...          GCKR
# 94  CCR5 is involved in immune response and has be...          CCR5
# 96  RPS6KA2 is involved in the regulation of cellu...       RNASET2
#
#     claude35_confidence                                    claude35_reason  \
# 5                   0.8  APOA5 is involved in lipid metabolism and has ...
# 7                   0.8  NPC1 is involved in cholesterol trafficking an...
# 16                  0.9  APOA5 is strongly associated with triglyceride...
# 19                  0.7  MFSD2A is involved in lipid transport and meta...
# 20                  0.9  LPA encodes lipoprotein(a), strongly associate...
# 23                  0.7  PRKCD encodes protein kinase C delta, involved...
# 24                  0.8  SLC6A4 encodes the serotonin transporter, whic...
# 31                  0.8  CCR5 is involved in immune response and has be...
# 32                  0.8  APOA5 is involved in lipid metabolism and has ...
# 34                  0.8  GAS7 is associated with intraocular pressure r...
# 40                  0.9  C4A directly encodes Complement Component 4, t...
# 41                  0.8  APOA5 is strongly associated with lipid metabo...
# 49                  0.7  LILRA5 is involved in neutrophil activation an...
# 53                  0.9  C4A directly encodes Complement Component 4, t...
# 55                  0.8  APOA5 is involved in lipid metabolism and has ...
# 56                  0.8  NPC1 is involved in cholesterol trafficking an...
# 58                  0.8  GCKR is a well-known regulator of glucose meta...
# 61                  0.8  APOA5 is involved in lipid metabolism and has ...
# 62                  0.8  APOA5 is involved in lipid metabolism and has ...
# 64                  0.7  MBD3L1 is involved in epigenetic regulation an...
# 65                  0.8  APOA5 is involved in lipid metabolism and has ...
# 66                  0.9  SHBG (Sex Hormone-Binding Globulin) is directl...
# 71                  0.8  APOA5 is involved in lipid metabolism and has ...
# 75                  0.8  GCKR is a well-known regulator of glucose and ...
# 85                  0.8  CARNS1 encodes carnosine synthase 1, involved ...
# 86                  0.9  C4A directly encodes Complement Component 4, t...
# 88                  0.6  TGFBR3L is involved in TGF-beta signaling, whi...
# 89                  0.8  NF1 is associated with neurofibromatosis type ...
# 91                  0.8  GCKR is a well-known regulator of glucose and ...
# 94                  0.8  CCR5 is involved in immune response and has be...
# 96                  0.7  RNASET2 is involved in RNA metabolism and cell...
#
#         llama3_pred  llama3_confidence  \
# 5             APOA4                0.8
# 7           ANKRD29                0.7
# 16            APOA1                0.8
# 19            BMP8A                0.7
# 20              LPA                0.8
# 23          CACNA1D                0.8
# 24            ADAP2                0.8
# 31             CCR5                0.8
# 32             ZPR1                0.8
# 34             GAS7                0.6
# 40              C4A                0.8
# 41            APOA4                0.8
# 49           CACNG6                0.8
# 53              C4A                0.8
# 55            APOA4                0.8
# 56            RBBP8                0.7
# 58             GCKR                0.8
# 61            APOA4                0.8
# 62            BACE1                0.8
# 64            ACTL9                0.8
# 65            APOA4                0.8
# 66            DNAH2                0.8
# 71            APOA4                0.8
# 75           ATRAID                0.8
# 85            GSTP1                0.8
# 86              C4A                0.8
# 88            ACTL9                0.8
# 89            EVI2A                0.8
# 91           ATRAID                0.8
# 94             CCR5                0.8
# 96  ENSG00...002790                0.8
#
#                                         llama3_reason
# 5   APOA4 has been implicated in sex determination...
# 7   ANKRD29 has been implicated in sex determinati...
# 16  APOA1 is a well-established regulator of trigl...
# 19  BMP8A has been implicated in sex determination...
# 20  Strong association with triglyceride levels an...
# 23  CACNA1D has been implicated in obesity and met...
# 24  ADAP2 has been implicated in sex-specific gene...
# 31  As a chemokine receptor, CCR5 has been implica...
# 32  ZPR1 has been implicated in sex determination ...
# 34  GAS7 has been implicated in the regulation of ...
# 40  Strong association with C4 protein concentrati...
# 41  APOA4 has been implicated in sex determination...
# 49  CACNG6 is a calcium channel regulator and has ...
# 53  Strong association with C4 protein concentrati...
# 55  APOA4 has been implicated in sex determination...
# 56  RBBP8 has been implicated in sex determination...
# 58  GCKR has been previously associated with metab...
# 61  APOA4 has been implicated in sex determination...
# 62  BACE1 has been implicated in sex determination...
# 64  ACTL9 has been implicated in sex determination...
# 65  APOA4 has been implicated in sex determination...
# 66  DNAH2 has been implicated in sex determination...
# 71  APOA4 has been implicated in sex determination...
# 75  ATRAID has been implicated in the regulation o...
# 85  GSTP1 is a glutathione S-transferase involved ...
# 86  Strong association with C4 protein concentrati...
# 88  ACTL9 has been implicated in sex determination...
# 89  EVI2A has been implicated in sex determination...
# 91  ATRAID has been implicated in the regulation o...
# 94  Previous studies have implicated CCR5 in COVID...
# 96  Previous studies have linked GPR31 to the regu...
